# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
x = pd.read_csv("NaN.csv")

# %%
x
# Out:
#      name  english_marks  maths_marks  hindi_marks  science_marks     city  \
# 0  sahil            45.0         39.0          NaN           13.0  gwalior
# 1   nitin            NaN         34.0         12.0           15.0      NaN
# 2  pankaj           39.0         46.0          3.0            NaN    delhi
# 3  neeraj           32.0          NaN         12.0           15.0     agra
# 4   vinay           40.0         35.0          NaN           43.0     pune
# 5   viraj            NaN         42.0         15.0           13.0      NaN
# 6   vijay           13.0         35.0          NaN            NaN   mumbai
# 7   kavya           33.0          NaN         45.0           15.0   indore
# 8   gagan           49.0         43.0         15.0           12.0      NaN
# 9  deepak           50.0         24.0         50.0           12.0   kanpur
#
#        id
# 0  3455.0
# 1  1642.0
# 2     NaN
# 3  3415.0
# 4  1512.0
# 5     NaN
# 6  1515.0
# 7  5145.0
# 8  1321.0
# 9  1551.0

# %% [markdown]
# # Find how many NaN values per column

# %%
nan_values = x.isnull().sum()

# %%
nan_values
# Out:
# name             0
# english_marks    2
# maths_marks      2
# hindi_marks      3
# science_marks    2
# city             3
# id               2
# dtype: int64

# %%
# see NaN values which column you see

# %%
nan_values[0:5]
# Out:
# name             0
# english_marks    2
# maths_marks      2
# hindi_marks      3
# science_marks    2
# dtype: int64

# %%
nan_values[5] # we seen that 5 column have 3 NaN values
# Out:
# 3

# %% [markdown]
# # Find total missing values in data

# %%
total_missing = nan_values.sum()

# %%
total_missing
# Out:
# 14

# %%
# we have total 14 missing values

# %% [markdown]
# # Find total cells in data

# %%
total_cells = np.product(x.shape)

# %%
total_cells
# Out:
# 70

# %% [markdown]
# # Find percent of data that is missing

# %%
percent_missing = (total_missing/total_cells)*100

# %%
percent_missing
# Out:
# 20.0

# %% [markdown]
# # Remove all the rows that contain a missing value

# %%
drop_row = x.dropna()

# %%
drop_row
# Out:
#      name  english_marks  maths_marks  hindi_marks  science_marks    city  \
# 9  deepak           50.0         24.0         50.0           12.0  kanpur
#
#        id
# 9  1551.0

# %%
# it means 9 row dont have any NaN values

# %%
x
# Out:
#      name  english_marks  maths_marks  hindi_marks  science_marks     city  \
# 0  sahil            45.0         39.0          NaN           13.0  gwalior
# 1   nitin            NaN         34.0         12.0           15.0      NaN
# 2  pankaj           39.0         46.0          3.0            NaN    delhi
# 3  neeraj           32.0          NaN         12.0           15.0     agra
# 4   vinay           40.0         35.0          NaN           43.0     pune
# 5   viraj            NaN         42.0         15.0           13.0      NaN
# 6   vijay           13.0         35.0          NaN            NaN   mumbai
# 7   kavya           33.0          NaN         45.0           15.0   indore
# 8   gagan           49.0         43.0         15.0           12.0      NaN
# 9  deepak           50.0         24.0         50.0           12.0   kanpur
#
#        id
# 0  3455.0
# 1  1642.0
# 2     NaN
# 3  3415.0
# 4  1512.0
# 5     NaN
# 6  1515.0
# 7  5145.0
# 8  1321.0
# 9  1551.0

# %% [markdown]
# # Remove all the column that contain a missing value

# %%
drop_col = x.dropna(axis = 1)

# %%
drop_col
# Out:
#      name
# 0  sahil
# 1   nitin
# 2  pankaj
# 3  neeraj
# 4   vinay
# 5   viraj
# 6   vijay
# 7   kavya
# 8   gagan
# 9  deepak

# %%
# it means 0 column dont have any NaN values

# %%
print("column in orignal data set",x.shape[1])
# Out:
# column in orignal data set 7

# %%
print("column after drop NaN value",drop_col.shape[1])
# Out:
# column after drop NaN value 1

# %%
x
# Out:
#      name  english_marks  maths_marks  hindi_marks  science_marks     city  \
# 0  sahil            45.0         39.0          NaN           13.0  gwalior
# 1   nitin            NaN         34.0         12.0           15.0      NaN
# 2  pankaj           39.0         46.0          3.0            NaN    delhi
# 3  neeraj           32.0          NaN         12.0           15.0     agra
# 4   vinay           40.0         35.0          NaN           43.0     pune
# 5   viraj            NaN         42.0         15.0           13.0      NaN
# 6   vijay           13.0         35.0          NaN            NaN   mumbai
# 7   kavya           33.0          NaN         45.0           15.0   indore
# 8   gagan           49.0         43.0         15.0           12.0      NaN
# 9  deepak           50.0         24.0         50.0           12.0   kanpur
#
#        id
# 0  3455.0
# 1  1642.0
# 2     NaN
# 3  3415.0
# 4  1512.0
# 5     NaN
# 6  1515.0
# 7  5145.0
# 8  1321.0
# 9  1551.0

# %% [markdown]
# # Replace all NaN values with 0

# %%
replace_NaN_0 = x.fillna(0)

# %%
replace_NaN_0
# Out:
#      name  english_marks  maths_marks  hindi_marks  science_marks     city  \
# 0  sahil            45.0         39.0          0.0           13.0  gwalior
# 1   nitin            0.0         34.0         12.0           15.0        0
# 2  pankaj           39.0         46.0          3.0            0.0    delhi
# 3  neeraj           32.0          0.0         12.0           15.0     agra
# 4   vinay           40.0         35.0          0.0           43.0     pune
# 5   viraj            0.0         42.0         15.0           13.0        0
# 6   vijay           13.0         35.0          0.0            0.0   mumbai
# 7   kavya           33.0          0.0         45.0           15.0   indore
# 8   gagan           49.0         43.0         15.0           12.0        0
# 9  deepak           50.0         24.0         50.0           12.0   kanpur
#
#        id
# 0  3455.0
# 1  1642.0
# 2     0.0
# 3  3415.0
# 4  1512.0
# 5     0.0
# 6  1515.0
# 7  5145.0
# 8  1321.0
# 9  1551.0

# %% [markdown]
# # Replace all NaN values with lower values

# %%
replace_NaN_lower = x.fillna(method = "bfill")

# %%
replace_NaN_lower
# Out:
#      name  english_marks  maths_marks  hindi_marks  science_marks     city  \
# 0  sahil            45.0         39.0         12.0           13.0  gwalior
# 1   nitin           39.0         34.0         12.0           15.0    delhi
# 2  pankaj           39.0         46.0          3.0           15.0    delhi
# 3  neeraj           32.0         35.0         12.0           15.0     agra
# 4   vinay           40.0         35.0         15.0           43.0     pune
# 5   viraj           13.0         42.0         15.0           13.0   mumbai
# 6   vijay           13.0         35.0         45.0           15.0   mumbai
# 7   kavya           33.0         43.0         45.0           15.0   indore
# 8   gagan           49.0         43.0         15.0           12.0   kanpur
# 9  deepak           50.0         24.0         50.0           12.0   kanpur
#
#        id
# 0  3455.0
# 1  1642.0
# 2  3415.0
# 3  3415.0
# 4  1512.0
# 5  1515.0
# 6  1515.0
# 7  5145.0
# 8  1321.0
# 9  1551.0

# %% [markdown]
# # Replace all NaN values with upper values

# %%
replace_NaN_upper = x.fillna(method = "ffill")

# %%
replace_NaN_upper
# Out:
#      name  english_marks  maths_marks  hindi_marks  science_marks     city  \
# 0  sahil            45.0         39.0          NaN           13.0  gwalior
# 1   nitin           45.0         34.0         12.0           15.0  gwalior
# 2  pankaj           39.0         46.0          3.0           15.0    delhi
# 3  neeraj           32.0         46.0         12.0           15.0     agra
# 4   vinay           40.0         35.0         12.0           43.0     pune
# 5   viraj           40.0         42.0         15.0           13.0     pune
# 6   vijay           13.0         35.0         15.0           13.0   mumbai
# 7   kavya           33.0         35.0         45.0           15.0   indore
# 8   gagan           49.0         43.0         15.0           12.0   indore
# 9  deepak           50.0         24.0         50.0           12.0   kanpur
#
#        id
# 0  3455.0
# 1  1642.0
# 2  1642.0
# 3  3415.0
# 4  1512.0
# 5  1512.0
# 6  1515.0
# 7  5145.0
# 8  1321.0
# 9  1551.0
